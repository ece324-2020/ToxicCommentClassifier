# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.18.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (50.3.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.4.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
############### upload data
# Mount Google drive to load data
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

path ='/content/drive/MyDrive/ece367/ECE324 project/dataProcessing/processed_data_aug/test.csv'

text_data = pd.read_csv(path, sep=',')
print(text_data)
print(text_data["toxic"].value_counts())
# Out:
#                     id  ... identity_hate
# 0     2a2805dc384e9b60  ...             1
# 1     cc738bd89c1a1dc5  ...             0
# 2     218bdcbae72b1def  ...             0
# 3     d3bf5e38c76a5c0d  ...             0
# 4     586a2aefd01e5316  ...             0
# ...                ...  ...           ...
# 2534  2489283ccba99a24  ...             0
# 2535  5e70615ce678ee05  ...             0
# 2536  5e0584dcf993c0aa  ...             0
# 2537  35243af9766437b5  ...             1
# 2538  71c6a5551bc1b17e  ...             0
#
# [2539 rows x 8 columns]
# 1    2063
# 0     476
# Name: toxic, dtype: int64

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext import data
import spacy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import argparse
import os
import datetime, time

# %%
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNN_LSTM(nn.Module):
    def __init__(self, embedding_dim, vocab, hidden_dim=100):
        super(CNN_LSTM, self).__init__()
        self.embedding = nn.Embedding.from_pretrained(vocab.vectors)
        self.hidden_dim = hidden_dim

        self.conv1 = nn.Conv2d(1, 100,kernel_size=(2,embedding_dim), padding = 1) #in_channels, out_chanels, kernel_size
        
        
        self.lstm1 = nn.LSTM(embedding_dim,hidden_dim)
        target_size = 1
        self.fc1 = nn.Linear(hidden_dim, target_size)

    def forward(self, x, lengths):
    #   embeds = self.word_embeddings(sentence)
    #     lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
    #     tag_space = self.hidden2tag(lstm_out.view(len(sentence), -1))
    #     tag_scores = F.log_softmax(tag_space, dim=1)
    #     return tag_scores
        
        x = self.embedding(x)
        # print('x.shape',x.shape)

        x = x.unsqueeze(0)
        # print('x = x.unsqueeze(0)',x.shape)
        x = x.transpose(1,2) # swaps 2nd and 3rd dimension
        # print('x = x.transpose(1,2)',x.shape)
        x = x.transpose(0,1) # swaps 1st and 2nd dimension, now it has the correct input (n_samples,channels, height, width)
        # print('x = x.transpose(0,1)',x.shape)
        x1 = F.relu(self.conv1(x)) 
        # print('x1 = F.relu(self.conv1(x))',x1.shape)
        
        x1 = x1.squeeze(3)
        # print('x1 = x1.squeeze(3)',x1.shape)
        pool1 = nn.MaxPool1d(x1.size(2), 1) #maxpool
        
        x = pool1(x1)
        # print('pool1 = nn.MaxPool1d(x1.size(2), 1)',x.shape)
        x = x.squeeze(2)
        x = x.unsqueeze(0)
        # print('x = x.squeeze(2)',x.shape)


        #  pack the word embeddings in the batch together and 
        # run the RNN on this object
        # x = pack_padded_sequence(x,lengths) 
        # print('x.shape',x.shape)
        x,(h,c) = self.lstm1(x)
        # print('x.shape',x.shape)
        # print('h.shape',h.shape)
        # print('len(h)',len(h))
        # print('(x.view(len(lengths),-1)).shape',(x.view(len(lengths),-1)).shape)
        h_result = self.fc1(h.squeeze(0))
        # h_result = F.log_softmax(tag_space, dim=1) --> change to this with multiple cat
        h_result = torch.sigmoid(h_result)
        

        return h_result.squeeze(1)

# %% [markdown]
# ## model

# %%
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNN_LSTM_2_conv(nn.Module):
    def __init__(self, embedding_dim, vocab, hidden_dim=100):
        super(CNN_LSTM_2_conv, self).__init__()
        self.embedding = nn.Embedding.from_pretrained(vocab.vectors)
        self.hidden_dim = hidden_dim

        self.conv1 = nn.Conv2d(1, 50,kernel_size=(2,embedding_dim)) #in_channels, out_chanels, kernel_size
        self.conv2 = nn.Conv2d(1, 50,kernel_size=(2,embedding_dim)) #in_channels, out_chanels, kernel_size
        
        
        self.lstm1 = nn.LSTM(embedding_dim,hidden_dim)
        target_size = 1
        self.fc1 = nn.Linear(hidden_dim, target_size)

    def forward(self, x, lengths):
    #   embeds = self.word_embeddings(sentence)
    #     lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
    #     tag_space = self.hidden2tag(lstm_out.view(len(sentence), -1))
    #     tag_scores = F.log_softmax(tag_space, dim=1)
    #     return tag_scores
        
        x = self.embedding(x)
        # print('x.shape',x.shape)

        x = x.unsqueeze(0)
        # print('x = x.unsqueeze(0)',x.shape)
        x = x.transpose(1,2) # swaps 2nd and 3rd dimension
        # print('x = x.transpose(1,2)',x.shape)
        x = x.transpose(0,1) # swaps 1st and 2nd dimension, now it has the correct input (n_samples,channels, height, width)
        # print('x = x.transpose(0,1)',x.shape)
        x1 = F.relu(self.conv1(x))
        x2 = F.relu(self.conv2(x)) 
        # print('x1 = F.relu(self.conv1(x))',x1.shape)
        
        x1 = x1.squeeze(3)
        x2 = x2.squeeze(3)
        # print('x1 = x1.squeeze(3) hahaha',x1.shape)
        pool1 = nn.MaxPool1d(x1.size(2), 1)
        pool2 = nn.MaxPool1d(x2.size(2), 1) #maxpool
        
        x1 = pool1(x1)
        x2 = pool2(x2)
        # print('x1 = x1.squeeze(3) here',x1.shape)

        x = torch.cat((x1,x2),1)
        # print('pool1 = nn.MaxPool1d(x1.size(2), 1)',x.shape)
        # x = concat.view(-1,100)
        # print('x = x.',x.shape)
        
        x = x.transpose(1,2)
        # print('x === x.squeeze(1)',x.shape)
        x = x.transpose(0,1)
        # print('x === x.squeeze(0)',x.shape)


        #  pack the word embeddings in the batch together and 
        # run the RNN on this object
        # x = pack_padded_sequence(x,lengths) 
        # print('x.shape',x.shape)
        x,(h,c) = self.lstm1(x)
        # print('x.shape',x.shape)
        # print('h.shape',h.shape)
        # print('len(h)',len(h))
        # print('(x.view(len(lengths),-1)).shape',(x.view(len(lengths),-1)).shape)
        h_result = self.fc1(h.squeeze(0))
        # h_result = F.log_softmax(tag_space, dim=1) --> change to this with multiple cat
        h_result = torch.sigmoid(h_result)
        

        return h_result.squeeze(1)

# %% [markdown]
# # New Section

# %%
x = torch.ones(2, 3)
# y = torch.ones(5, 3)
y = torch.from_numpy(np.array([[1,0,0],[0,1,1]])).float()
print(x)
print(y)
temp = (x == y)
# print(temp)
sum_all = 0
comb_correct = 0
avg_acc = 0
for i in temp:
  print(i)
  if torch.equal(i, torch.BoolTensor([True, True,True])):
        comb_correct += 1
  sum_all = torch.count_nonzero(i)
  acc = sum_all/len(i)
  avg_acc += acc
  print(avg_acc)
print(sum_all)
print(comb_correct)
print(avg_acc/3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# tensor([[1., 0., 0.],
#         [0., 1., 1.]])
# tensor([ True, False, False])
# tensor(0.3333)
# tensor([False,  True,  True])
# tensor(1.)
# tensor(2)
# 0
# tensor(0.3333)

# %% [markdown]
# ## training function

# %%
def batch_label(batch, cat):
    if cat == 'toxic':
      return batch.toxic.float() 
    elif cat == 'severe_toxic':
      return batch.severe_toxic.float() 
    elif cat == 'obscene':
      return batch.obscene.float() 
    elif cat == 'threat':
      return batch.threat.float() 
    elif cat == 'insult':
      return batch.insult.float() 
    elif cat == 'identity_hate':
      return batch.identity_hate.float() 
    else:
      print("ERROR: wrong category name")

def get_binary_accuracy(model,batch_input,batch_input_length,learning_rate,labels):  
    valCorrect = 0
    valRunningLoss = 0.0
    valNumberOfBatches = 0
    valTotal = 0
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    outputs = model(batch_input, batch_input_length)

    loss = criterion(outputs, labels)
    valRunningLoss += loss.item()
    outputs = (outputs>0.5).float()
    
    valCorrect += (outputs == labels).sum().item()
    valTotal += labels.size(0)
    # print('valTotal += labels.size(0)',valTotal)
    valNumberOfBatches += 1
    valRunningLoss = valRunningLoss/valNumberOfBatches
    valCorrect = valCorrect/valTotal

    return valRunningLoss,valCorrect,outputs,valTotal


def evaluate_combined_correct(toxic_outputs,toxic_labels,severe_toxic_outputs,severe_toxic_labels,\
                                                        obscene_outputs,obscene_labels,threat_outputs,threat_labels,insult_outputs,insult_labels,identity_hate_outputs,identity_hate_labels):
    comb_correct = 0
    comb_outputs = torch.cat((toxic_outputs.unsqueeze(0), severe_toxic_outputs.unsqueeze(0),obscene_outputs.unsqueeze(0),\
                              threat_outputs.unsqueeze(0),insult_outputs.unsqueeze(0),identity_hate_outputs.unsqueeze(0)),0)
    comb_outputs = torch.transpose(comb_outputs, 0, 1)
    # print('##############')
    # print('comb_outputs',comb_outputs)
    # print('comb_outputs shape',comb_outputs.shape)

    comb_labels = torch.cat((toxic_labels.unsqueeze(0), severe_toxic_labels.unsqueeze(0),obscene_labels.unsqueeze(0),\
                              threat_labels.unsqueeze(0),insult_labels.unsqueeze(0),identity_hate_labels.unsqueeze(0)),0)
    comb_labels = torch.transpose(comb_labels, 0, 1)
    # print('comb_labels',comb_labels)
    # print('comb_labels shape',comb_labels.shape)
    # print('##############')
    temp = (comb_labels == comb_outputs)
    for i in temp:
      
      comb_correct += torch.count_nonzero(i)/len(i)
      # print(comb_correct)
      
      # if torch.equal(i, torch.BoolTensor([True, True,True, True,True, True])):
      #   comb_correct += 1
    # print('comb_correct',comb_correct/(toxic_outputs.shape[0]))
    # print('##############')
    return comb_correct/(toxic_outputs.shape[0])
    
def evaluate_binary_loss_correct(data_iter,toxic_model,severe_toxic_model,obscene_model,threat_model,insult_model,identity_hate_model,cat,learning_rate):
   
    val_comb_correct = 0
    valTotal = 0
    total_batch = 0

    with torch.no_grad():
      for batch in data_iter:
        total_batch += 1
        batch_input, batch_input_length = batch.text
        
        toxic_valLabels = batch_label(batch,cat[0])  
        severe_toxic_valLabels = batch_label(batch,cat[1]) 
        obscene_valLabels = batch_label(batch,cat[2]) 
        threat_valLabels = batch_label(batch,cat[3]) 
        insult_valLabels = batch_label(batch,cat[4]) 
        identity_hate_valLabels = batch_label(batch,cat[5])          

        toxic_valRunningLoss,toxic_valCorrect,toxic_valOutputs,val_batch_total = get_binary_accuracy(toxic_model,batch_input,batch_input_length,learning_rate,toxic_valLabels)
        severe_toxic_valRunningLoss, severe_toxic_valCorrect, severe_toxic_valOutputs, val_batch_total = get_binary_accuracy( severe_toxic_model,batch_input,batch_input_length,learning_rate, severe_toxic_valLabels)
        obscene_valRunningLoss, obscene_valCorrect, obscene_valOutputs, val_batch_total = get_binary_accuracy( obscene_model,batch_input,batch_input_length,learning_rate, obscene_valLabels)
        threat_valRunningLoss,threat_valCorrect,threat_valOutputs,val_batch_total = get_binary_accuracy(threat_model,batch_input,batch_input_length,learning_rate,threat_valLabels)
        
        insult_valRunningLoss, insult_valCorrect, insult_valOutputs, val_batch_total = get_binary_accuracy( insult_model,batch_input,batch_input_length,learning_rate, insult_valLabels)
        identity_hate_valRunningLoss, identity_hate_valCorrect, identity_hate_valOutputs, val_batch_total = get_binary_accuracy(identity_hate_model,batch_input,batch_input_length,learning_rate, identity_hate_valLabels)
        
        val_comb_correct += evaluate_combined_correct(toxic_valOutputs,toxic_valLabels,severe_toxic_valOutputs,severe_toxic_valLabels,obscene_valOutputs,obscene_valLabels,threat_valOutputs,threat_valLabels, insult_valOutputs,insult_valLabels,identity_hate_valOutputs,identity_hate_valLabels)
        valTotal += val_batch_total
    # print statistics for every epoch)
    return toxic_valRunningLoss,toxic_valCorrect,\
    severe_toxic_valRunningLoss, severe_toxic_valCorrect, \
    obscene_valRunningLoss, obscene_valCorrect, \
    threat_valRunningLoss,threat_valCorrect,\
    insult_valRunningLoss, insult_valCorrect,\
    identity_hate_valRunningLoss, identity_hate_valCorrect, \
    val_comb_correct,total_batch

def train_classifier(cat ,vocab,train_iter, val_iter, test_iter,seed, learning_rate, epochs, model, emb_dim, rnn_hidden_dim, num_filt): 
    torch.manual_seed(seed)    
    
    epochCount = []  
    

    ######## toxic ###########
    toxic_model = model(emb_dim, vocab)
    toxic_criterion = nn.BCEWithLogitsLoss()
    toxic_optimizer = optim.Adam(toxic_model.parameters(), lr=learning_rate)

    toxic_lossCount = []
    toxic_accCount = []
    
    toxic_valLossCount = []
    toxic_valAccCount = []    

    toxic_testLossCount = []
    toxic_testAccCount = []

    ######## severe_toxic ###########
    severe_toxic_model = model(emb_dim, vocab)
    severe_toxic_criterion = nn.BCEWithLogitsLoss()
    severe_toxic_optimizer = optim.Adam(severe_toxic_model.parameters(), lr=learning_rate)

    severe_toxic_valLossCount = []
    severe_toxic_valAccCount = []
    
    severe_toxic_lossCount = []
    severe_toxic_accCount = []

    severe_toxic_testLossCount = []
    severe_toxic_testAccCount = []

    ######## obscene ###########
    obscene_model = model(emb_dim, vocab)
    obscene_criterion = nn.BCEWithLogitsLoss()
    obscene_optimizer = optim.Adam(obscene_model.parameters(), lr=learning_rate)

    obscene_valLossCount = []
    obscene_valAccCount = []
    
    obscene_lossCount = []
    obscene_accCount = []

    obscene_testLossCount = []
    obscene_testAccCount = []

    ######## threat ###########
    threat_model = model(emb_dim, vocab)
    threat_criterion = nn.BCEWithLogitsLoss()
    threat_optimizer = optim.Adam(threat_model.parameters(), lr=learning_rate)

    threat_valLossCount = []
    threat_valAccCount = []
    
    threat_lossCount = []
    threat_accCount = []

    threat_testLossCount = []
    threat_testAccCount = []

    ######## insult ###########
    insult_model = model(emb_dim, vocab)
    insult_criterion = nn.BCEWithLogitsLoss()
    insult_optimizer = optim.Adam(insult_model.parameters(), lr=learning_rate)


    insult_valLossCount = []
    insult_valAccCount = []
    
    insult_lossCount = []
    insult_accCount = []

    insult_testLossCount = []
    insult_testAccCount = []

    ######## identity_hate ###########
    identity_hate_model = model(emb_dim, vocab)
    identity_hate_criterion = nn.BCEWithLogitsLoss()
    identity_hate_optimizer = optim.Adam(identity_hate_model.parameters(), lr=learning_rate)


    identity_hate_valLossCount = []
    identity_hate_valAccCount = []
    
    identity_hate_lossCount = []
    identity_hate_accCount = []

    identity_hate_testLossCount = []
    identity_hate_testAccCount = []

    ######## total ################
    total_prediction_train_accuracy = []
    total_prediction_val_accuracy = []
    total_prediction_test_accuracy = []

    total_prediction_train_loss = []
    total_prediction_val_loss = []
    total_prediction_test_loss = []

    
    
    for epoch in range(epochs):  # loop over the dataset multiple times
        print('epoch----------------------------------------------',epoch)
        
        ######## toxic ###########
        toxic_correct = 0
        toxic_total = 0
        toxic_runningLoss = 0.0
        toxic_numberOfBatches = 0

        ######## severe_toxic ###########
        severe_toxic_correct = 0
        severe_toxic_total = 0
        severe_toxic_runningLoss = 0.0
        severe_toxic_numberOfBatches = 0        

        ######## obscene ###########
        obscene_correct = 0
        obscene_total = 0
        obscene_runningLoss = 0.0
        obscene_numberOfBatches = 0        

        ######## threat ###########
        threat_correct = 0
        threat_total = 0
        threat_runningLoss = 0.0
        threat_numberOfBatches = 0        

        ######## insult ###########
        insult_correct = 0
        insult_total = 0
        insult_runningLoss = 0.0
        insult_numberOfBatches = 0

        ######## identity_hate ###########
        identity_hate_correct = 0
        identity_hate_total = 0
        identity_hate_runningLoss = 0.0
        identity_hate_numberOfBatches = 0

        ######## total ###########
        val_total = 0
        test_total = 0

        comb_correct = 0
        val_comb_correct = 0
        test_comb_correct = 0
        
        
        for i, batch in enumerate(train_iter, 0):
            # print('i',i)
            # get the set of text sentences in the batch and length of the sentence sequences
            batch_input, batch_input_length = batch.text
            ########### toxic #################################################
            toxic_labels = batch_label(batch,cat[0]) 
            # print('toxic_labels',toxic_labels)
        
            # zero the parameter gradients
            toxic_optimizer.zero_grad()

            # forward + backward + optimize
            toxic_outputs = toxic_model(batch_input, batch_input_length)
            toxic_loss = toxic_criterion(toxic_outputs, toxic_labels)
            toxic_loss.backward()
            toxic_optimizer.step()
            ########### toxic #################################################

            ##### severe_toxic #############################################
            severe_toxic_labels = batch_label(batch,cat[1]) 
        
            # zero the parameter gradients
            severe_toxic_optimizer.zero_grad()
            # print('threat_labels',threat_labels)
            # forward + backward + optimize
            severe_toxic_outputs = severe_toxic_model(batch_input, batch_input_length)
            # print('outputs',threat_outputs)
            severe_toxic_loss = severe_toxic_criterion(severe_toxic_outputs, severe_toxic_labels)
            # print('threat_outputs',threat_outputs)
            # print('threat_loss',threat_loss)

            severe_toxic_loss.backward()
            severe_toxic_optimizer.step()
            #### severe_toxic ####################################################

            ########## obscene #############################################
            obscene_labels = batch_label(batch,cat[2]) 
        
            # zero the parameter gradients
            obscene_optimizer.zero_grad()
            # print('threat_labels',threat_labels)
            # forward + backward + optimize
            obscene_outputs = obscene_model(batch_input, batch_input_length)
            # print('outputs',threat_outputs)
            obscene_loss = obscene_criterion(obscene_outputs, obscene_labels)
            # print('threat_outputs',threat_outputs)
            # print('threat_loss',threat_loss)

            obscene_loss.backward()
            obscene_optimizer.step()
            #### obscene ####################################################

            ########## threat #############################################
            threat_labels = batch_label(batch,cat[3]) 
        
            # zero the parameter gradients
            threat_optimizer.zero_grad()
            # print('threat_labels',threat_labels)
            # forward + backward + optimize
            threat_outputs = threat_model(batch_input, batch_input_length)
            # print('outputs',threat_outputs)
            threat_loss = threat_criterion(threat_outputs, threat_labels)
            # print('threat_outputs',threat_outputs)
            # print('threat_loss',threat_loss)

            threat_loss.backward()
            threat_optimizer.step()
            #### threat ####################################################

             ########## insult #############################################
            insult_labels = batch_label(batch,cat[4]) 
        
            # zero the parameter gradients
            insult_optimizer.zero_grad()
            # print('threat_labels',threat_labels)
            # forward + backward + optimize
            insult_outputs = insult_model(batch_input, batch_input_length)
            # print('outputs',threat_outputs)
            insult_loss = insult_criterion(insult_outputs, insult_labels)
            # print('threat_outputs',threat_outputs)
            # print('threat_loss',threat_loss)

            insult_loss.backward()
            insult_optimizer.step()
            #### threat ####################################################

             ########## identity_hate #############################################
            identity_hate_labels = batch_label(batch,cat[5]) 
        
            # zero the parameter gradients
            identity_hate_optimizer.zero_grad()
            # print('threat_labels',threat_labels)
            # forward + backward + optimize
            identity_hate_outputs = identity_hate_model(batch_input, batch_input_length)
            # print('outputs',threat_outputs)
            identity_hate_loss = identity_hate_criterion(identity_hate_outputs, identity_hate_labels)
            # print('threat_outputs',threat_outputs)
            # print('threat_loss',threat_loss)

            identity_hate_loss.backward()
            identity_hate_optimizer.step()
            #### threat ####################################################
            
            ##### evaluate training accuracy ###############################
            with torch.no_grad():
              
              toxic_outputs = (toxic_outputs>0.5).float()
              # print('changed_out',toxic_outputs)
              toxic_correct += (toxic_outputs == toxic_labels).sum().item()
              # print('toxic_correct',toxic_correct)
              # print('toxic_outputs train',toxic_outputs)
              severe_toxic_outputs = (severe_toxic_outputs>0.5).float()
              #   # print('threat_outputs_changed',threat_outputs)
              severe_toxic_correct += (severe_toxic_outputs == severe_toxic_labels).sum().item()

              obscene_outputs = (obscene_outputs>0.5).float()
              #   # print('threat_outputs_changed',threat_outputs)
              obscene_correct += (obscene_outputs == obscene_labels).sum().item()              
            
              threat_outputs = (threat_outputs>0.5).float()
              #   # print('threat_outputs_changed',threat_outputs)
              threat_correct += (threat_outputs == threat_labels).sum().item()

              insult_outputs = (insult_outputs>0.5).float()
              #   # print('threat_outputs_changed',threat_outputs)
              insult_correct += (insult_outputs == insult_labels).sum().item()

              identity_hate_outputs = (identity_hate_outputs>0.5).float()
              #   # print('threat_outputs_changed',threat_outputs)
              identity_hate_correct += (identity_hate_outputs == identity_hate_labels).sum().item()

              comb_correct += evaluate_combined_correct(toxic_outputs,toxic_labels,severe_toxic_outputs,severe_toxic_labels,\
                                                        obscene_outputs,obscene_labels,threat_outputs,threat_labels,insult_outputs,insult_labels,identity_hate_outputs,identity_hate_labels)           
              
              ##### evaluate training accuracy ###############################    
            
            toxic_runningLoss += toxic_loss.item()
            # print('toxic_runningLoss',toxic_runningLoss)
            # count the number of batches and samples
            toxic_numberOfBatches += 1
            toxic_total += toxic_labels.size(0)

            severe_toxic_runningLoss += severe_toxic_loss.item()
            # print('threat_runningLoss',threat_runningLoss)
            # count the number of batches and samples
            severe_toxic_numberOfBatches += 1
            severe_toxic_total += severe_toxic_labels.size(0)

            obscene_runningLoss += obscene_loss.item()
            # print('threat_runningLoss',threat_runningLoss)
            # count the number of batches and samples
            obscene_numberOfBatches += 1
            obscene_total += obscene_labels.size(0)

            threat_runningLoss += threat_loss.item()
            # print('threat_runningLoss',threat_runningLoss)
            # count the number of batches and samples
            threat_numberOfBatches += 1
            threat_total += threat_labels.size(0)

            insult_runningLoss += insult_loss.item()
            # print('threat_runningLoss',threat_runningLoss)
            # count the number of batches and samples
            insult_numberOfBatches += 1
            insult_total += insult_labels.size(0)

            identity_hate_runningLoss += identity_hate_loss.item()
            # print('threat_runningLoss',threat_runningLoss)
            # count the number of batches and samples
            identity_hate_numberOfBatches += 1
            identity_hate_total += identity_hate_labels.size(0)

        
        # print('threat_total',threat_total)
        # print('toxic_total',toxic_total)
        
        toxic_runningLoss = toxic_runningLoss/toxic_numberOfBatches
        toxic_correct = toxic_correct/toxic_total
        toxic_lossCount += [toxic_runningLoss]
        toxic_accCount += [toxic_correct]

        severe_toxic_runningLoss = severe_toxic_runningLoss/severe_toxic_numberOfBatches
        print('-----------------severe_toxic_correct',severe_toxic_correct)
        print('-----------------severe_toxic_total',severe_toxic_total)

        severe_toxic_correct = severe_toxic_correct/severe_toxic_total
        print('-----------------severe_toxic_correct',severe_toxic_correct)
        severe_toxic_lossCount += [severe_toxic_runningLoss]
        severe_toxic_accCount += [severe_toxic_correct]

        obscene_runningLoss = obscene_runningLoss/obscene_numberOfBatches
        obscene_correct = obscene_correct/obscene_total
        obscene_lossCount += [obscene_runningLoss]
        obscene_accCount += [obscene_correct]

        threat_runningLoss = threat_runningLoss/threat_numberOfBatches
        threat_correct = threat_correct/threat_total
        threat_lossCount += [threat_runningLoss]
        threat_accCount += [threat_correct]

        insult_runningLoss = insult_runningLoss/insult_numberOfBatches
        insult_correct = insult_correct/insult_total
        insult_lossCount += [insult_runningLoss]
        insult_accCount += [insult_correct]

        identity_hate_runningLoss = identity_hate_runningLoss/identity_hate_numberOfBatches
        identity_hate_correct = identity_hate_correct/identity_hate_total
        identity_hate_lossCount += [identity_hate_runningLoss]
        identity_hate_accCount += [identity_hate_correct]
        
        epochCount += [epoch+1]             
        
        avg_loss_each = (toxic_runningLoss + severe_toxic_runningLoss + obscene_runningLoss + threat_runningLoss\
                              + insult_runningLoss + identity_hate_runningLoss)/6

        
        total_prediction_train_loss += [avg_loss_each]
        total_prediction_train_accuracy += [comb_correct/i]

        ######### validation dataset ###################################
        print('cat',cat)
        toxic_valRunningLoss,toxic_valCorrect,severe_toxic_valRunningLoss,severe_toxic_valCorrect,obscene_valRunningLoss,obscene_valCorrect,threat_valRunningLoss,threat_valCorrect,\
        insult_valRunningLoss,insult_valCorrect,identity_hate_valRunningLoss,identity_hate_valCorrect,val_comb_correct,val_total= \
        evaluate_binary_loss_correct(val_iter,toxic_model,severe_toxic_model,obscene_model,threat_model,insult_model,identity_hate_model,cat,learning_rate)
        
        avg_val_loss_each = (toxic_valRunningLoss + severe_toxic_valRunningLoss + obscene_valRunningLoss + threat_valRunningLoss\
        + insult_valRunningLoss + identity_hate_valRunningLoss)/6

        total_prediction_val_loss += [avg_val_loss_each]
        total_prediction_val_accuracy += [val_comb_correct/val_total]

        toxic_valLossCount += [toxic_valRunningLoss]
        toxic_valAccCount += [toxic_valCorrect]

        severe_toxic_valLossCount += [severe_toxic_valRunningLoss]
        severe_toxic_valAccCount += [severe_toxic_valCorrect]

        obscene_valLossCount += [obscene_valRunningLoss]
        obscene_valAccCount += [obscene_valCorrect]

        threat_valLossCount += [threat_valRunningLoss]
        threat_valAccCount += [threat_valCorrect]

        insult_valLossCount += [insult_valRunningLoss]
        insult_valAccCount += [insult_valCorrect]
        
        identity_hate_valLossCount += [identity_hate_valRunningLoss]
        identity_hate_valAccCount += [identity_hate_valCorrect]

        ######### validation dataset ###################################
        
        ######### testing dataset ###################################
        toxic_testRunningLoss,toxic_testCorrect,severe_toxic_testRunningLoss,severe_toxic_testCorrect,obscene_testRunningLoss,obscene_testCorrect,threat_testRunningLoss,threat_testCorrect,\
        insult_testRunningLoss,insult_testCorrect,identity_hate_testRunningLoss,identity_hate_testCorrect,test_comb_correct,test_total= \
        evaluate_binary_loss_correct(test_iter,toxic_model,severe_toxic_model,obscene_model,threat_model,insult_model,identity_hate_model,cat,learning_rate)
        
        avg_test_loss_each = (toxic_testRunningLoss + severe_toxic_testRunningLoss + obscene_testRunningLoss + threat_testRunningLoss\
                              + insult_testRunningLoss + identity_hate_testRunningLoss)/6

        total_prediction_test_loss += [avg_test_loss_each]
        total_prediction_test_accuracy += [test_comb_correct/test_total]

        toxic_testLossCount += [toxic_testRunningLoss]
        toxic_testAccCount += [toxic_testCorrect]

        severe_toxic_testLossCount += [severe_toxic_testRunningLoss]
        severe_toxic_testAccCount += [severe_toxic_testCorrect]

        obscene_testLossCount += [obscene_testRunningLoss]
        obscene_testAccCount += [obscene_testCorrect]

        threat_testLossCount += [threat_testRunningLoss]
        threat_testAccCount += [threat_testCorrect] 
        
        insult_testLossCount += [insult_testRunningLoss]
        insult_testAccCount += [insult_testCorrect]
        
        identity_hate_testLossCount += [identity_hate_testRunningLoss]
        identity_hate_testAccCount += [identity_hate_testCorrect]      

        print('[%d] toxic_train loss: %.3f, toxic_train acc: %.3f, toxic_validation loss: %.3f, toxic_validation acc: %.3f, \
        toxic_testing loss: %.3f, toxic_testing acc: %.3f ' %
                      (epoch + 1, toxic_runningLoss, toxic_correct,toxic_valRunningLoss, toxic_valCorrect,toxic_testRunningLoss,toxic_testCorrect))
        
        print('[%d] severe_toxic_train loss: %.3f, severe_toxic_train acc: %.3f, severe_toxic_validation loss: %.3f, severe_toxic_validation acc: %.3f,\
        severe_toxic_testing loss: %.3f, severe_toxic_testing acc: %.3f ' %
                      (epoch + 1, severe_toxic_runningLoss, severe_toxic_correct, severe_toxic_valRunningLoss, severe_toxic_valCorrect,severe_toxic_testRunningLoss,severe_toxic_testCorrect))
        
        print('[%d] obscene_train loss: %.3f, obscene_train acc: %.3f, obscene_validation loss: %.3f, obscene_validation acc: %.3f,\
        obscene_testing loss: %.3f, obscene_testing acc: %.3f ' %
                      (epoch + 1, obscene_runningLoss,obscene_correct, obscene_valRunningLoss, obscene_valCorrect, obscene_testRunningLoss, obscene_testCorrect))
        
        print('[%d] threat_train loss: %.3f, threat_train acc: %.3f, threat_validation loss: %.3f, threat_validation acc: %.3f,\
        threat_testing loss: %.3f, threat_testing acc: %.3f ' %
                      (epoch + 1, threat_runningLoss, threat_correct, threat_valRunningLoss, threat_valCorrect,threat_testRunningLoss,threat_testCorrect))
        
        print('[%d] insult_train loss: %.3f, insult_train acc: %.3f, insult_validation loss: %.3f, insult_validation acc: %.3f,\
        insult_testing loss: %.3f, insult_testing acc: %.3f ' %
                      (epoch + 1, insult_runningLoss, insult_correct, insult_valRunningLoss, insult_valCorrect, insult_testRunningLoss, insult_testCorrect))
        
        print('[%d] identity_hate_train loss: %.3f, identity_hate_train acc: %.3f, identity_hate_validation loss: %.3f, identity_hate_validation acc: %.3f,\
        identity_hate_testing loss: %.3f, identity_hate_testing acc: %.3f ' %
                      (epoch + 1, identity_hate_runningLoss, identity_hate_correct, identity_hate_valRunningLoss, identity_hate_valCorrect, identity_hate_testRunningLoss, identity_hate_testCorrect))
        
        print('[%d] comb_train loss: %.3f, comb_train acc: %.3f, comb_validation loss: %.3f, comb_validation acc: %.3f,\
        comb_testing loss: %.3f, comb_testing acc: %.3f  ' %
                      (epoch + 1,avg_loss_each, comb_correct/i,\
                       avg_val_loss_each,val_comb_correct/val_total,\
                       avg_test_loss_each,test_comb_correct/test_total))
 
# ------------------------------- plot --------------------------------------------
    
    ################# toxic ###############################
    plt.title("toxic_Loss Curve")
    plt.plot(epochCount, toxic_lossCount, label="Training")
    plt.plot(epochCount, toxic_valLossCount, label="Validation")
    plt.plot(epochCount, toxic_testLossCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("toxic_Accuracy Curve")
    plt.plot(epochCount, toxic_accCount, label = "Training")
    plt.plot(epochCount, toxic_valAccCount, label = "Validation")
    plt.plot(epochCount, toxic_testAccCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    ################# severe_toxic ###############################
    plt.title("severe_toxic_Loss Curve")
    plt.plot(epochCount, severe_toxic_lossCount, label="Training")
    plt.plot(epochCount, severe_toxic_valLossCount, label="Validation")
    plt.plot(epochCount, severe_toxic_testLossCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("severe_toxic_Accuracy Curve")
    plt.plot(epochCount, severe_toxic_accCount, label = "Training")
    plt.plot(epochCount, severe_toxic_valAccCount, label = "Validation")
    plt.plot(epochCount, severe_toxic_testAccCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    ################# obscene ###############################
    plt.title("obscene_Loss Curve")
    plt.plot(epochCount, obscene_lossCount, label="Training")
    plt.plot(epochCount, obscene_valLossCount, label="Validation")
    plt.plot(epochCount, obscene_testLossCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("obscene_Accuracy Curve")
    plt.plot(epochCount, obscene_accCount, label = "Training")
    plt.plot(epochCount, obscene_valAccCount, label = "Validation")
    plt.plot(epochCount, obscene_testAccCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    ################# threat ###############################
    plt.title("threat_Loss Curve")
    plt.plot(epochCount, threat_lossCount, label="Training")
    plt.plot(epochCount, threat_valLossCount, label="Validation")
    plt.plot(epochCount, threat_testLossCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()


    plt.title("threat_Accuracy Curve")
    plt.plot(epochCount, threat_accCount, label = "Training")
    plt.plot(epochCount, threat_valAccCount, label = "Validation")
    plt.plot(epochCount, threat_testAccCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    ################# insult ###############################
    plt.title("insult_Loss Curve")
    plt.plot(epochCount, insult_lossCount, label="Training")
    plt.plot(epochCount, insult_valLossCount, label="Validation")
    plt.plot(epochCount, insult_testLossCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("insult_Accuracy Curve")
    plt.plot(epochCount, insult_accCount, label = "Training")
    plt.plot(epochCount, insult_valAccCount, label = "Validation")
    plt.plot(epochCount, insult_testAccCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()


    ################# identity_hate ###############################
    plt.title("identity_hate_Loss Curve")
    plt.plot(epochCount,identity_hate_lossCount, label="Training")
    plt.plot(epochCount, identity_hate_valLossCount, label="Validation")
    plt.plot(epochCount, identity_hate_testLossCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("identity_hate_Accuracy Curve")
    plt.plot(epochCount, identity_hate_accCount, label = "Training")
    plt.plot(epochCount, identity_hate_valAccCount, label = "Validation")
    plt.plot(epochCount, identity_hate_testAccCount, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    ################# total ###############################

    plt.title("total_Loss Curve")
    plt.plot(epochCount, total_prediction_train_loss, label="Training")
    plt.plot(epochCount, total_prediction_val_loss, label="Validation")
    plt.plot(epochCount, total_prediction_test_loss, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("total_Accuracy Curve")
    plt.plot(epochCount, total_prediction_train_accuracy, label = "Training")
    plt.plot(epochCount, total_prediction_val_accuracy, label = "Validation")
    plt.plot(epochCount, total_prediction_test_accuracy, label="Testing")
    plt.xlabel("Number of Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    torch.save(toxic_model,cat[0]+'_'+'model_together_CNN_LSTM.pt')
    torch.save(severe_toxic_model,cat[1]+'_'+'model_together_CNN_LSTM.pt')
    torch.save(obscene_model,cat[2]+'_'+'model_together_CNN_LSTM.pt')
    torch.save(threat_model,cat[3]+'_'+'model_together_CNN_LSTM.pt')
    torch.save(insult_model,cat[4]+'_'+'model_together_CNN_LSTM.pt')
    torch.save(identity_hate_model,cat[5]+'_'+'model_together_CNN_LSTM.pt')


    # return total_prediction_train,total_prediction_val,total_prediction_test,lossCount,valLossCount,testLossCount

# %%
def trainRNN_R(seed = 0, batch_size = 64, learning_rate = 0.001, epochs = 25, model = CNN_LSTM, emb_dim = 100, rnn_hidden_dim = 100, num_filt = 50):
    
  torch.manual_seed(seed)

  COMMENT_TEXT    = data.Field(sequential=True,lower=True, tokenize='spacy', include_lengths=True)
  TOXIC           = data.Field(sequential=False, use_vocab=False)
  SEVERE_TOXIC    = data.Field(sequential=False, use_vocab=False)
  OBSCENE         = data.Field(sequential=False, use_vocab=False)
  THREAT          = data.Field(sequential=False, use_vocab=False)
  INSULT          = data.Field(sequential=False, use_vocab=False)
  IDENTITY_HATE   = data.Field(sequential=False, use_vocab=False)

  train_data, val_data, test_data = data.TabularDataset.splits(
          # path='/content/drive/MyDrive/ece367/ECE324 project/dataProcessing/new_processed_data/', train='train.csv',
          # validation='valid.csv', test='test.csv', format='csv',
          # skip_header=True, fields=[('id', None), ('text', COMMENT_TEXT), ('toxic', TOXIC), ('severe_toxic', SEVERE_TOXIC), ('obscene', OBSCENE), ('threat', THREAT), ('insult', INSULT), ('identity_hate', IDENTITY_HATE)])
          
          
          path='/content/drive/MyDrive/ece367/ECE324 project/dataProcessing/processed_data_aug_v2/', train='train.csv',
          validation='valid.csv', test='test.csv', format='csv',
          skip_header=True, fields=[('id', None), ('text', COMMENT_TEXT), ('toxic', TOXIC), ('severe_toxic', SEVERE_TOXIC), ('obscene', OBSCENE), ('threat', THREAT), ('insult', INSULT), ('identity_hate', IDENTITY_HATE)])
          
          # path='/content/drive/MyDrive/ece367/ECE324 project/dataProcessing/multi_loose_large_data/', train='train.csv',
          # validation='valid.csv', test='test.csv', format='csv',
          # skip_header=True, fields=[('id', None), ('text', COMMENT_TEXT), ('toxic', TOXIC), ('severe_toxic', SEVERE_TOXIC), ('obscene', OBSCENE), ('threat', THREAT), ('insult', INSULT), ('identity_hate', IDENTITY_HATE)])
          
  train_iter, val_iter, test_iter = data.BucketIterator.splits(
      (train_data, val_data, test_data), batch_sizes=(batch_size, batch_size,batch_size),
      sort_key=lambda x: len(x.text), device=None, sort_within_batch=True, repeat=False)

  COMMENT_TEXT.build_vocab(train_data, val_data, test_data)

  COMMENT_TEXT.vocab.load_vectors(torchtext.vocab.GloVe(name='6B', dim=100))
  vocab = COMMENT_TEXT.vocab

  def save_vocab(vocab):
    import pickle
    output = open('together_vocab.pkl', 'wb')
    pickle.dump(vocab, output)
    output.close()
  save_vocab(vocab)

  cat = ['toxic','severe_toxic','obscene','threat','insult','identity_hate']

  train_classifier(cat,vocab,train_iter, val_iter, test_iter,seed, learning_rate, epochs, model, emb_dim, rnn_hidden_dim, num_filt)

# %% [markdown]
# # TRAIN

# %%
trainRNN_R(seed = 0, batch_size = 64, learning_rate = 0.001, epochs = 30, model = CNN_LSTM_2_conv, emb_dim = 100, rnn_hidden_dim = 100, num_filt = 50)
# Out:
# epoch---------------------------------------------- 0
# -----------------severe_toxic_correct 20253
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7812451782132387
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [1] toxic_train loss: 0.472, toxic_train acc: 0.840, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.528, toxic_testing acc: 0.786
# [1] severe_toxic_train loss: 0.698, severe_toxic_train acc: 0.781, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [1] obscene_train loss: 0.582, obscene_train acc: 0.769, obscene_validation loss: 0.514, obscene_validation acc: 0.800,        obscene_testing loss: 0.544, obscene_testing acc: 0.881
# [1] threat_train loss: 0.697, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [1] insult_train loss: 0.616, insult_train acc: 0.706, insult_validation loss: 0.431, insult_validation acc: 0.875,        insult_testing loss: 0.542, insult_testing acc: 0.833
# [1] identity_hate_train loss: 0.698, identity_hate_train acc: 0.786, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [1] comb_train loss: 0.627, comb_train acc: 0.781, comb_validation loss: 0.569, comb_validation acc: 0.801,        comb_testing loss: 0.616, comb_testing acc: 0.798
# epoch---------------------------------------------- 1
# -----------------severe_toxic_correct 20300
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7830581700354884
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [2] toxic_train loss: 0.470, toxic_train acc: 0.843, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.528, toxic_testing acc: 0.786
# [2] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [2] obscene_train loss: 0.556, obscene_train acc: 0.835, obscene_validation loss: 0.504, obscene_validation acc: 0.800,        obscene_testing loss: 0.517, obscene_testing acc: 0.905
# [2] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [2] insult_train loss: 0.586, insult_train acc: 0.784, insult_validation loss: 0.420, insult_validation acc: 0.925,        insult_testing loss: 0.537, insult_testing acc: 0.857
# [2] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [2] comb_train loss: 0.615, comb_train acc: 0.807, comb_validation loss: 0.565, comb_validation acc: 0.801,        comb_testing loss: 0.610, comb_testing acc: 0.802
# epoch---------------------------------------------- 2
# -----------------severe_toxic_correct 20300
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7830581700354884
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [3] toxic_train loss: 0.464, toxic_train acc: 0.848, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.526, toxic_testing acc: 0.786
# [3] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [3] obscene_train loss: 0.552, obscene_train acc: 0.845, obscene_validation loss: 0.496, obscene_validation acc: 0.825,        obscene_testing loss: 0.515, obscene_testing acc: 0.905
# [3] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [3] insult_train loss: 0.581, insult_train acc: 0.796, insult_validation loss: 0.407, insult_validation acc: 0.975,        insult_testing loss: 0.536, insult_testing acc: 0.857
# [3] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [3] comb_train loss: 0.613, comb_train acc: 0.811, comb_validation loss: 0.562, comb_validation acc: 0.812,        comb_testing loss: 0.609, comb_testing acc: 0.811
# epoch---------------------------------------------- 3
# -----------------severe_toxic_correct 20300
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7830581700354884
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [4] toxic_train loss: 0.425, toxic_train acc: 0.899, toxic_validation loss: 0.391, toxic_validation acc: 0.925,         toxic_testing loss: 0.478, toxic_testing acc: 0.857
# [4] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [4] obscene_train loss: 0.548, obscene_train acc: 0.855, obscene_validation loss: 0.491, obscene_validation acc: 0.825,        obscene_testing loss: 0.522, obscene_testing acc: 0.881
# [4] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [4] insult_train loss: 0.575, insult_train acc: 0.813, insult_validation loss: 0.407, insult_validation acc: 0.975,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [4] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [4] comb_train loss: 0.605, comb_train acc: 0.824, comb_validation loss: 0.561, comb_validation acc: 0.818,        comb_testing loss: 0.602, comb_testing acc: 0.817
# epoch---------------------------------------------- 4
# -----------------severe_toxic_correct 20300
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7830581700354884
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [5] toxic_train loss: 0.418, toxic_train acc: 0.914, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.475, toxic_testing acc: 0.857
# [5] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [5] obscene_train loss: 0.543, obscene_train acc: 0.864, obscene_validation loss: 0.495, obscene_validation acc: 0.825,        obscene_testing loss: 0.526, obscene_testing acc: 0.881
# [5] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [5] insult_train loss: 0.569, insult_train acc: 0.822, insult_validation loss: 0.412, insult_validation acc: 0.950,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [5] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [5] comb_train loss: 0.602, comb_train acc: 0.829, comb_validation loss: 0.562, comb_validation acc: 0.819,        comb_testing loss: 0.603, comb_testing acc: 0.820
# epoch---------------------------------------------- 5
# -----------------severe_toxic_correct 20300
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7830581700354884
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [6] toxic_train loss: 0.414, toxic_train acc: 0.923, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.494, toxic_testing acc: 0.833
# [6] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [6] obscene_train loss: 0.540, obscene_train acc: 0.870, obscene_validation loss: 0.494, obscene_validation acc: 0.800,        obscene_testing loss: 0.515, obscene_testing acc: 0.905
# [6] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [6] insult_train loss: 0.566, insult_train acc: 0.830, insult_validation loss: 0.410, insult_validation acc: 0.950,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [6] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [6] comb_train loss: 0.600, comb_train acc: 0.833, comb_validation loss: 0.562, comb_validation acc: 0.818,        comb_testing loss: 0.604, comb_testing acc: 0.820
# epoch---------------------------------------------- 6
# -----------------severe_toxic_correct 20300
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7830581700354884
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [7] toxic_train loss: 0.412, toxic_train acc: 0.928, toxic_validation loss: 0.389, toxic_validation acc: 0.925,         toxic_testing loss: 0.446, toxic_testing acc: 0.905
# [7] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [7] obscene_train loss: 0.539, obscene_train acc: 0.875, obscene_validation loss: 0.491, obscene_validation acc: 0.850,        obscene_testing loss: 0.520, obscene_testing acc: 0.905
# [7] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [7] insult_train loss: 0.562, insult_train acc: 0.840, insult_validation loss: 0.423, insult_validation acc: 0.925,        insult_testing loss: 0.545, insult_testing acc: 0.833
# [7] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [7] comb_train loss: 0.599, comb_train acc: 0.837, comb_validation loss: 0.564, comb_validation acc: 0.817,        comb_testing loss: 0.598, comb_testing acc: 0.817
# epoch---------------------------------------------- 7
# -----------------severe_toxic_correct 20303
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7831738929177596
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [8] toxic_train loss: 0.409, toxic_train acc: 0.933, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.442, toxic_testing acc: 0.929
# [8] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [8] obscene_train loss: 0.537, obscene_train acc: 0.880, obscene_validation loss: 0.505, obscene_validation acc: 0.800,        obscene_testing loss: 0.528, obscene_testing acc: 0.881
# [8] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [8] insult_train loss: 0.559, insult_train acc: 0.847, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.527, insult_testing acc: 0.881
# [8] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [8] comb_train loss: 0.597, comb_train acc: 0.839, comb_validation loss: 0.563, comb_validation acc: 0.823,        comb_testing loss: 0.596, comb_testing acc: 0.824
# epoch---------------------------------------------- 8
# -----------------severe_toxic_correct 20304
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.78321246721185
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [9] toxic_train loss: 0.407, toxic_train acc: 0.937, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.441, toxic_testing acc: 0.929
# [9] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [9] obscene_train loss: 0.533, obscene_train acc: 0.887, obscene_validation loss: 0.496, obscene_validation acc: 0.825,        obscene_testing loss: 0.523, obscene_testing acc: 0.881
# [9] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [9] insult_train loss: 0.556, insult_train acc: 0.853, insult_validation loss: 0.408, insult_validation acc: 0.975,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [9] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [9] comb_train loss: 0.596, comb_train acc: 0.842, comb_validation loss: 0.562, comb_validation acc: 0.823,        comb_testing loss: 0.596, comb_testing acc: 0.824
# epoch---------------------------------------------- 9
# -----------------severe_toxic_correct 20307
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7833281900941212
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [10] toxic_train loss: 0.405, toxic_train acc: 0.941, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.450, toxic_testing acc: 0.905
# [10] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [10] obscene_train loss: 0.532, obscene_train acc: 0.891, obscene_validation loss: 0.504, obscene_validation acc: 0.800,        obscene_testing loss: 0.522, obscene_testing acc: 0.881
# [10] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [10] insult_train loss: 0.555, insult_train acc: 0.856, insult_validation loss: 0.412, insult_validation acc: 0.950,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [10] identity_hate_train loss: 0.693, identity_hate_train acc: 0.787, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [10] comb_train loss: 0.595, comb_train acc: 0.844, comb_validation loss: 0.564, comb_validation acc: 0.821,        comb_testing loss: 0.598, comb_testing acc: 0.823
# epoch---------------------------------------------- 10
# -----------------severe_toxic_correct 20311
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.783482487270483
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [11] toxic_train loss: 0.404, toxic_train acc: 0.944, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.452, toxic_testing acc: 0.881
# [11] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [11] obscene_train loss: 0.530, obscene_train acc: 0.896, obscene_validation loss: 0.532, obscene_validation acc: 0.775,        obscene_testing loss: 0.557, obscene_testing acc: 0.833
# [11] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [11] insult_train loss: 0.552, insult_train acc: 0.862, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [11] identity_hate_train loss: 0.693, identity_hate_train acc: 0.788, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [11] comb_train loss: 0.594, comb_train acc: 0.847, comb_validation loss: 0.567, comb_validation acc: 0.823,        comb_testing loss: 0.604, comb_testing acc: 0.823
# epoch---------------------------------------------- 11
# -----------------severe_toxic_correct 20313
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7835596358586638
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [12] toxic_train loss: 0.403, toxic_train acc: 0.946, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.453, toxic_testing acc: 0.905
# [12] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.784, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.693, severe_toxic_testing acc: 0.357
# [12] obscene_train loss: 0.530, obscene_train acc: 0.896, obscene_validation loss: 0.491, obscene_validation acc: 0.825,        obscene_testing loss: 0.502, obscene_testing acc: 0.929
# [12] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [12] insult_train loss: 0.553, insult_train acc: 0.858, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.536, insult_testing acc: 0.857
# [12] identity_hate_train loss: 0.693, identity_hate_train acc: 0.788, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [12] comb_train loss: 0.594, comb_train acc: 0.847, comb_validation loss: 0.561, comb_validation acc: 0.814,        comb_testing loss: 0.595, comb_testing acc: 0.815
# epoch---------------------------------------------- 12
# -----------------severe_toxic_correct 20317
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7837139330350255
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [13] toxic_train loss: 0.402, toxic_train acc: 0.948, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.447, toxic_testing acc: 0.905
# [13] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.784, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.688, severe_toxic_testing acc: 0.381
# [13] obscene_train loss: 0.530, obscene_train acc: 0.895, obscene_validation loss: 0.507, obscene_validation acc: 0.800,        obscene_testing loss: 0.521, obscene_testing acc: 0.905
# [13] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [13] insult_train loss: 0.549, insult_train acc: 0.868, insult_validation loss: 0.415, insult_validation acc: 0.950,        insult_testing loss: 0.541, insult_testing acc: 0.833
# [13] identity_hate_train loss: 0.693, identity_hate_train acc: 0.789, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [13] comb_train loss: 0.593, comb_train acc: 0.848, comb_validation loss: 0.565, comb_validation acc: 0.820,        comb_testing loss: 0.597, comb_testing acc: 0.819
# epoch---------------------------------------------- 13
# -----------------severe_toxic_correct 20311
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.783482487270483
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [14] toxic_train loss: 0.401, toxic_train acc: 0.949, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.446, toxic_testing acc: 0.905
# [14] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.783, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.691, severe_toxic_testing acc: 0.357
# [14] obscene_train loss: 0.529, obscene_train acc: 0.897, obscene_validation loss: 0.493, obscene_validation acc: 0.825,        obscene_testing loss: 0.509, obscene_testing acc: 0.905
# [14] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [14] insult_train loss: 0.549, insult_train acc: 0.869, insult_validation loss: 0.415, insult_validation acc: 0.950,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [14] identity_hate_train loss: 0.693, identity_hate_train acc: 0.789, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [14] comb_train loss: 0.593, comb_train acc: 0.849, comb_validation loss: 0.563, comb_validation acc: 0.817,        comb_testing loss: 0.594, comb_testing acc: 0.819
# epoch---------------------------------------------- 14
# -----------------severe_toxic_correct 20319
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7837910816232063
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [15] toxic_train loss: 0.400, toxic_train acc: 0.951, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.449, toxic_testing acc: 0.905
# [15] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.784, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.687, severe_toxic_testing acc: 0.381
# [15] obscene_train loss: 0.527, obscene_train acc: 0.901, obscene_validation loss: 0.501, obscene_validation acc: 0.800,        obscene_testing loss: 0.517, obscene_testing acc: 0.905
# [15] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [15] insult_train loss: 0.546, insult_train acc: 0.875, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.530, insult_testing acc: 0.881
# [15] identity_hate_train loss: 0.692, identity_hate_train acc: 0.789, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [15] comb_train loss: 0.592, comb_train acc: 0.851, comb_validation loss: 0.562, comb_validation acc: 0.825,        comb_testing loss: 0.595, comb_testing acc: 0.825
# epoch---------------------------------------------- 15
# -----------------severe_toxic_correct 20322
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7839068045054776
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [16] toxic_train loss: 0.400, toxic_train acc: 0.951, toxic_validation loss: 0.390, toxic_validation acc: 0.925,         toxic_testing loss: 0.451, toxic_testing acc: 0.881
# [16] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.784, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.685, severe_toxic_testing acc: 0.381
# [16] obscene_train loss: 0.526, obscene_train acc: 0.904, obscene_validation loss: 0.504, obscene_validation acc: 0.800,        obscene_testing loss: 0.517, obscene_testing acc: 0.905
# [16] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [16] insult_train loss: 0.546, insult_train acc: 0.875, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [16] identity_hate_train loss: 0.692, identity_hate_train acc: 0.790, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [16] comb_train loss: 0.592, comb_train acc: 0.852, comb_validation loss: 0.563, comb_validation acc: 0.824,        comb_testing loss: 0.596, comb_testing acc: 0.823
# epoch---------------------------------------------- 16
# -----------------severe_toxic_correct 20326
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7840611016818392
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [17] toxic_train loss: 0.400, toxic_train acc: 0.953, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.491, toxic_testing acc: 0.833
# [17] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.784, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.684, severe_toxic_testing acc: 0.381
# [17] obscene_train loss: 0.525, obscene_train acc: 0.906, obscene_validation loss: 0.516, obscene_validation acc: 0.800,        obscene_testing loss: 0.533, obscene_testing acc: 0.881
# [17] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [17] insult_train loss: 0.545, insult_train acc: 0.876, insult_validation loss: 0.414, insult_validation acc: 0.950,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [17] identity_hate_train loss: 0.692, identity_hate_train acc: 0.789, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [17] comb_train loss: 0.591, comb_train acc: 0.852, comb_validation loss: 0.566, comb_validation acc: 0.820,        comb_testing loss: 0.605, comb_testing acc: 0.821
# epoch---------------------------------------------- 17
# -----------------severe_toxic_correct 20327
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7840996759759297
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [18] toxic_train loss: 0.401, toxic_train acc: 0.951, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.457, toxic_testing acc: 0.881
# [18] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.784, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.684, severe_toxic_testing acc: 0.381
# [18] obscene_train loss: 0.525, obscene_train acc: 0.907, obscene_validation loss: 0.499, obscene_validation acc: 0.825,        obscene_testing loss: 0.514, obscene_testing acc: 0.905
# [18] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [18] insult_train loss: 0.545, insult_train acc: 0.878, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [18] identity_hate_train loss: 0.692, identity_hate_train acc: 0.790, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [18] comb_train loss: 0.591, comb_train acc: 0.853, comb_validation loss: 0.562, comb_validation acc: 0.821,        comb_testing loss: 0.595, comb_testing acc: 0.822
# epoch---------------------------------------------- 18
# -----------------severe_toxic_correct 20339
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7845625675050146
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [19] toxic_train loss: 0.399, toxic_train acc: 0.953, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.448, toxic_testing acc: 0.905
# [19] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.785, severe_toxic_validation loss: 0.693, severe_toxic_validation acc: 0.325,        severe_toxic_testing loss: 0.685, severe_toxic_testing acc: 0.381
# [19] obscene_train loss: 0.524, obscene_train acc: 0.907, obscene_validation loss: 0.506, obscene_validation acc: 0.800,        obscene_testing loss: 0.513, obscene_testing acc: 0.905
# [19] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [19] insult_train loss: 0.543, insult_train acc: 0.883, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.530, insult_testing acc: 0.857
# [19] identity_hate_train loss: 0.692, identity_hate_train acc: 0.790, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [19] comb_train loss: 0.591, comb_train acc: 0.854, comb_validation loss: 0.563, comb_validation acc: 0.825,        comb_testing loss: 0.594, comb_testing acc: 0.825
# epoch---------------------------------------------- 19
# -----------------severe_toxic_correct 20353
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7851026076222805
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [20] toxic_train loss: 0.400, toxic_train acc: 0.952, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.448, toxic_testing acc: 0.905
# [20] severe_toxic_train loss: 0.693, severe_toxic_train acc: 0.785, severe_toxic_validation loss: 0.674, severe_toxic_validation acc: 0.375,        severe_toxic_testing loss: 0.698, severe_toxic_testing acc: 0.357
# [20] obscene_train loss: 0.529, obscene_train acc: 0.898, obscene_validation loss: 0.483, obscene_validation acc: 0.850,        obscene_testing loss: 0.514, obscene_testing acc: 0.905
# [20] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [20] insult_train loss: 0.542, insult_train acc: 0.884, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [20] identity_hate_train loss: 0.692, identity_hate_train acc: 0.790, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [20] comb_train loss: 0.592, comb_train acc: 0.852, comb_validation loss: 0.556, comb_validation acc: 0.824,        comb_testing loss: 0.595, comb_testing acc: 0.824
# epoch---------------------------------------------- 20
# -----------------severe_toxic_correct 20486
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.7902329887363061
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [21] toxic_train loss: 0.400, toxic_train acc: 0.952, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.440, toxic_testing acc: 0.929
# [21] severe_toxic_train loss: 0.691, severe_toxic_train acc: 0.790, severe_toxic_validation loss: 0.674, severe_toxic_validation acc: 0.375,        severe_toxic_testing loss: 0.684, severe_toxic_testing acc: 0.381
# [21] obscene_train loss: 0.524, obscene_train acc: 0.908, obscene_validation loss: 0.493, obscene_validation acc: 0.825,        obscene_testing loss: 0.515, obscene_testing acc: 0.905
# [21] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [21] insult_train loss: 0.543, insult_train acc: 0.881, insult_validation loss: 0.420, insult_validation acc: 0.950,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [21] identity_hate_train loss: 0.692, identity_hate_train acc: 0.791, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [21] comb_train loss: 0.591, comb_train acc: 0.855, comb_validation loss: 0.560, comb_validation acc: 0.828,        comb_testing loss: 0.592, comb_testing acc: 0.827
# epoch---------------------------------------------- 21
# -----------------severe_toxic_correct 20629
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.795749112791236
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [22] toxic_train loss: 0.399, toxic_train acc: 0.954, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.498, toxic_testing acc: 0.833
# [22] severe_toxic_train loss: 0.690, severe_toxic_train acc: 0.796, severe_toxic_validation loss: 0.617, severe_toxic_validation acc: 0.525,        severe_toxic_testing loss: 0.654, severe_toxic_testing acc: 0.452
# [22] obscene_train loss: 0.523, obscene_train acc: 0.912, obscene_validation loss: 0.489, obscene_validation acc: 0.825,        obscene_testing loss: 0.520, obscene_testing acc: 0.881
# [22] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [22] insult_train loss: 0.542, insult_train acc: 0.885, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [22] identity_hate_train loss: 0.692, identity_hate_train acc: 0.791, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.693, identity_hate_testing acc: 0.762
# [22] comb_train loss: 0.590, comb_train acc: 0.858, comb_validation loss: 0.548, comb_validation acc: 0.825,        comb_testing loss: 0.597, comb_testing acc: 0.826
# epoch---------------------------------------------- 22
# -----------------severe_toxic_correct 20883
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.8055469834902022
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [23] toxic_train loss: 0.398, toxic_train acc: 0.954, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.441, toxic_testing acc: 0.929
# [23] severe_toxic_train loss: 0.687, severe_toxic_train acc: 0.806, severe_toxic_validation loss: 0.638, severe_toxic_validation acc: 0.475,        severe_toxic_testing loss: 0.673, severe_toxic_testing acc: 0.405
# [23] obscene_train loss: 0.523, obscene_train acc: 0.911, obscene_validation loss: 0.515, obscene_validation acc: 0.775,        obscene_testing loss: 0.520, obscene_testing acc: 0.905
# [23] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [23] insult_train loss: 0.540, insult_train acc: 0.888, insult_validation loss: 0.420, insult_validation acc: 0.950,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [23] identity_hate_train loss: 0.692, identity_hate_train acc: 0.791, identity_hate_validation loss: 0.693, identity_hate_validation acc: 0.725,        identity_hate_testing loss: 0.691, identity_hate_testing acc: 0.762
# [23] comb_train loss: 0.589, comb_train acc: 0.860, comb_validation loss: 0.558, comb_validation acc: 0.829,        comb_testing loss: 0.591, comb_testing acc: 0.828
# epoch---------------------------------------------- 23
# -----------------severe_toxic_correct 21209
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.8181222033636785
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [24] toxic_train loss: 0.399, toxic_train acc: 0.954, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.448, toxic_testing acc: 0.905
# [24] severe_toxic_train loss: 0.683, severe_toxic_train acc: 0.818, severe_toxic_validation loss: 0.606, severe_toxic_validation acc: 0.550,        severe_toxic_testing loss: 0.626, severe_toxic_testing acc: 0.548
# [24] obscene_train loss: 0.523, obscene_train acc: 0.911, obscene_validation loss: 0.508, obscene_validation acc: 0.800,        obscene_testing loss: 0.529, obscene_testing acc: 0.881
# [24] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [24] insult_train loss: 0.540, insult_train acc: 0.889, insult_validation loss: 0.414, insult_validation acc: 0.950,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [24] identity_hate_train loss: 0.682, identity_hate_train acc: 0.825, identity_hate_validation loss: 0.637, identity_hate_validation acc: 0.875,        identity_hate_testing loss: 0.641, identity_hate_testing acc: 0.905
# [24] comb_train loss: 0.587, comb_train acc: 0.868, comb_validation loss: 0.541, comb_validation acc: 0.840,        comb_testing loss: 0.577, comb_testing acc: 0.837
# epoch---------------------------------------------- 24
# -----------------severe_toxic_correct 21669
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.8358663786452708
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [25] toxic_train loss: 0.398, toxic_train acc: 0.954, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.448, toxic_testing acc: 0.905
# [25] severe_toxic_train loss: 0.677, severe_toxic_train acc: 0.836, severe_toxic_validation loss: 0.542, severe_toxic_validation acc: 0.725,        severe_toxic_testing loss: 0.572, severe_toxic_testing acc: 0.714
# [25] obscene_train loss: 0.521, obscene_train acc: 0.915, obscene_validation loss: 0.510, obscene_validation acc: 0.800,        obscene_testing loss: 0.529, obscene_testing acc: 0.881
# [25] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [25] insult_train loss: 0.542, insult_train acc: 0.886, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [25] identity_hate_train loss: 0.670, identity_hate_train acc: 0.859, identity_hate_validation loss: 0.617, identity_hate_validation acc: 0.925,        identity_hate_testing loss: 0.649, identity_hate_testing acc: 0.881
# [25] comb_train loss: 0.584, comb_train acc: 0.876, comb_validation loss: 0.526, comb_validation acc: 0.847,        comb_testing loss: 0.570, comb_testing acc: 0.845
# epoch---------------------------------------------- 25
# -----------------severe_toxic_correct 22035
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.8499845702823638
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [26] toxic_train loss: 0.398, toxic_train acc: 0.956, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.448, toxic_testing acc: 0.905
# [26] severe_toxic_train loss: 0.671, severe_toxic_train acc: 0.850, severe_toxic_validation loss: 0.486, severe_toxic_validation acc: 0.875,        severe_toxic_testing loss: 0.550, severe_toxic_testing acc: 0.762
# [26] obscene_train loss: 0.521, obscene_train acc: 0.915, obscene_validation loss: 0.509, obscene_validation acc: 0.800,        obscene_testing loss: 0.530, obscene_testing acc: 0.881
# [26] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [26] insult_train loss: 0.542, insult_train acc: 0.885, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [26] identity_hate_train loss: 0.663, identity_hate_train acc: 0.877, identity_hate_validation loss: 0.620, identity_hate_validation acc: 0.950,        identity_hate_testing loss: 0.644, identity_hate_testing acc: 0.905
# [26] comb_train loss: 0.581, comb_train acc: 0.882, comb_validation loss: 0.517, comb_validation acc: 0.852,        comb_testing loss: 0.565, comb_testing acc: 0.848
# epoch---------------------------------------------- 26
# -----------------severe_toxic_correct 22343
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.8618654528622126
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [27] toxic_train loss: 0.399, toxic_train acc: 0.955, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.448, toxic_testing acc: 0.905
# [27] severe_toxic_train loss: 0.666, severe_toxic_train acc: 0.862, severe_toxic_validation loss: 0.486, severe_toxic_validation acc: 0.875,        severe_toxic_testing loss: 0.552, severe_toxic_testing acc: 0.738
# [27] obscene_train loss: 0.523, obscene_train acc: 0.912, obscene_validation loss: 0.528, obscene_validation acc: 0.775,        obscene_testing loss: 0.530, obscene_testing acc: 0.881
# [27] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [27] insult_train loss: 0.539, insult_train acc: 0.891, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [27] identity_hate_train loss: 0.659, identity_hate_train acc: 0.887, identity_hate_validation loss: 0.607, identity_hate_validation acc: 0.950,        identity_hate_testing loss: 0.631, identity_hate_testing acc: 0.929
# [27] comb_train loss: 0.580, comb_train acc: 0.886, comb_validation loss: 0.518, comb_validation acc: 0.851,        comb_testing loss: 0.563, comb_testing acc: 0.850
# epoch---------------------------------------------- 27
# -----------------severe_toxic_correct 22651
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.8737463354420614
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [28] toxic_train loss: 0.398, toxic_train acc: 0.957, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.440, toxic_testing acc: 0.929
# [28] severe_toxic_train loss: 0.662, severe_toxic_train acc: 0.874, severe_toxic_validation loss: 0.488, severe_toxic_validation acc: 0.850,        severe_toxic_testing loss: 0.551, severe_toxic_testing acc: 0.738
# [28] obscene_train loss: 0.524, obscene_train acc: 0.909, obscene_validation loss: 0.511, obscene_validation acc: 0.800,        obscene_testing loss: 0.529, obscene_testing acc: 0.881
# [28] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [28] insult_train loss: 0.538, insult_train acc: 0.894, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [28] identity_hate_train loss: 0.655, identity_hate_train acc: 0.897, identity_hate_validation loss: 0.600, identity_hate_validation acc: 0.975,        identity_hate_testing loss: 0.635, identity_hate_testing acc: 0.929
# [28] comb_train loss: 0.578, comb_train acc: 0.890, comb_validation loss: 0.514, comb_validation acc: 0.851,        comb_testing loss: 0.563, comb_testing acc: 0.852
# epoch---------------------------------------------- 28
# -----------------severe_toxic_correct 22827
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.880535411201975
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [29] toxic_train loss: 0.398, toxic_train acc: 0.956, toxic_validation loss: 0.388, toxic_validation acc: 0.925,         toxic_testing loss: 0.454, toxic_testing acc: 0.905
# [29] severe_toxic_train loss: 0.659, severe_toxic_train acc: 0.881, severe_toxic_validation loss: 0.475, severe_toxic_validation acc: 0.925,        severe_toxic_testing loss: 0.548, severe_toxic_testing acc: 0.738
# [29] obscene_train loss: 0.519, obscene_train acc: 0.920, obscene_validation loss: 0.493, obscene_validation acc: 0.825,        obscene_testing loss: 0.519, obscene_testing acc: 0.905
# [29] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [29] insult_train loss: 0.536, insult_train acc: 0.898, insult_validation loss: 0.405, insult_validation acc: 0.975,        insult_testing loss: 0.526, insult_testing acc: 0.881
# [29] identity_hate_train loss: 0.651, identity_hate_train acc: 0.906, identity_hate_validation loss: 0.620, identity_hate_validation acc: 0.950,        identity_hate_testing loss: 0.637, identity_hate_testing acc: 0.929
# [29] comb_train loss: 0.576, comb_train acc: 0.895, comb_validation loss: 0.512, comb_validation acc: 0.855,        comb_testing loss: 0.563, comb_testing acc: 0.852
# epoch---------------------------------------------- 29
# -----------------severe_toxic_correct 22980
# -----------------severe_toxic_total 25924
# -----------------severe_toxic_correct 0.8864372781978089
# cat ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# [30] toxic_train loss: 0.399, toxic_train acc: 0.954, toxic_validation loss: 0.390, toxic_validation acc: 0.925,         toxic_testing loss: 0.448, toxic_testing acc: 0.905
# [30] severe_toxic_train loss: 0.657, severe_toxic_train acc: 0.886, severe_toxic_validation loss: 0.465, severe_toxic_validation acc: 0.925,        severe_toxic_testing loss: 0.535, severe_toxic_testing acc: 0.786
# [30] obscene_train loss: 0.520, obscene_train acc: 0.918, obscene_validation loss: 0.538, obscene_validation acc: 0.750,        obscene_testing loss: 0.530, obscene_testing acc: 0.881
# [30] threat_train loss: 0.693, threat_train acc: 0.796, threat_validation loss: 0.693, threat_validation acc: 0.700,        threat_testing loss: 0.693, threat_testing acc: 0.762
# [30] insult_train loss: 0.537, insult_train acc: 0.896, insult_validation loss: 0.413, insult_validation acc: 0.950,        insult_testing loss: 0.535, insult_testing acc: 0.857
# [30] identity_hate_train loss: 0.649, identity_hate_train acc: 0.910, identity_hate_validation loss: 0.604, identity_hate_validation acc: 0.975,        identity_hate_testing loss: 0.630, identity_hate_testing acc: 0.929
# [30] comb_train loss: 0.576, comb_train acc: 0.895, comb_validation loss: 0.517, comb_validation acc: 0.852,        comb_testing loss: 0.562, comb_testing acc: 0.849

# %%
import pickle
import math

def tokenizer(string):
    nlp = spacy.load('en')
    return nlp(string)

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

def subjective_bot(model_path, vocab_path):
  model_baseline = torch.load(model_path)

  with open(vocab_path, 'rb') as f:
    vocab = pickle.load(f)

  while True:

      print("Enter a sentence")
      sentence = input()

      sentencelist = tokenizer(sentence)
      temp = []
      for i in range(len(sentencelist)):
          temp.append(vocab.stoi[str(sentencelist[i])])
      sentence_tensor = torch.LongTensor([temp]).permute(1, 0)
      sentence_length = torch.LongTensor([len(temp)])

      baseline = model_baseline(sentence_tensor, sentence_length)
      print(baseline)

# %%
subjective_bot('/content/obscene_model_together_CNN_LSTM.pt','/content/vocab.pkl')
# Out:
# Enter a sentence
# why is it you
# tensor([3.8783e-09], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# oh my god
# tensor([1.1121e-05], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# fuck fuck
# tensor([1.], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# what is happening
# tensor([1.0654e-09], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# i hate you so much
# tensor([6.8603e-09], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# fuck you fuck you
# tensor([1.], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# what the hell
# tensor([1.2209e-05], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# o got please
# tensor([1.7257e-06], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# i hate hate hate hamburger
# tensor([2.8479e-05], grad_fn=<SqueezeBackward1>)
# Enter a sentence
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
#     567         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-0e0baaf3bad9> in <module>()
# ----> 1 subjective_bot('/content/obscene_model_together_CNN_LSTM.pt','/content/vocab.pkl')
#
# <ipython-input-33-6ba4519d739f> in subjective_bot(model_path, vocab_path)
#      18
#      19       print("Enter a sentence")
# ---> 20       sentence = input()
#      21
#      22       sentencelist = tokenizer(sentence)
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
